# %%
from bokeh.plotting import figure, output_file, show
import pandas as pd
import os
import numpy as np
from bokeh.io import output_notebook

# %%
p = figure(plot_width=400, plot_height=400)

# %%
df = pd.read_csv("~/tmp/perdata.csv")

# %%
df["Labels"] = [ x.split('_', 6)[-1] for x in df['Labels']]
df["p90"] = df["p90"] / 1000.0

# %%
for label in df["Labels"].unique():
    ll = df[df["Labels"]==label]
    ll.sort_values(by=["NumThreads"])
    p.circle(ll["NumThreads"], ll["p90"], name=label, legend=label)

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7da1eb01-ef39-4b6d-b991-8106fbb7dec3">Loading BokehJS ...</span>
#     </div>

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="7331af1f-13d1-4591-a8cd-9582a33f749c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#7331af1f-13d1-4591-a8cd-9582a33f749c").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7331af1f-13d1-4591-a8cd-9582a33f749c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7331af1f-13d1-4591-a8cd-9582a33f749c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b6bbcef0-aabf-4dc7-9bc1-d35c68fcd3df":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[64,64,64,64,16,16],"y":[24.671,22.392,23.887,22.471,8.812,8.725]}},"id":"9fb7d972-232c-42f5-84c8-e6f91f616ea0","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[64],"y":[6.348]}},"id":"2161deed-edfa-4b32-a001-9d8032461695","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[64],"y":[9.425]}},"id":"266053d1-5738-4444-b16a-e9c516dace7d","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"da2311d7-0c28-4639-a6bc-78a2094b8ffd","type":"ColumnDataSource"},"glyph":{"id":"ff0067b7-debf-4efc-be3a-b573d6fbe140","type":"Circle"},"hover_glyph":null,"name":"serveronly","nonselection_glyph":{"id":"99fe8e7a-1c48-46ce-afd3-7257f39965fc","type":"Circle"},"selection_glyph":null},"id":"432f09a6-fe77-4e9e-984a-3232ad0cd89f","type":"GlyphRenderer"},{"attributes":{"label":{"value":"both"},"renderers":[{"id":"d7404c0a-7228-48f5-bfce-7fb38da38896","type":"GlyphRenderer"}]},"id":"d2b433c4-2634-43ae-a174-3ae810698095","type":"LegendItem"},{"attributes":{},"id":"c52054c5-760e-4550-9efd-7eb5f816b9a3","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4acbafb9-12eb-48d3-a282-5d3804b1514a","type":"Circle"},{"attributes":{"data_source":{"id":"9fb7d972-232c-42f5-84c8-e6f91f616ea0","type":"ColumnDataSource"},"glyph":{"id":"85e2e4a2-c5bf-4db6-a5c6-6576f75de201","type":"Circle"},"hover_glyph":null,"name":"both","nonselection_glyph":{"id":"7a24cda5-e2f4-4b99-91f4-70418b235227","type":"Circle"},"selection_glyph":null},"id":"d7404c0a-7228-48f5-bfce-7fb38da38896","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"eb9a8519-4ff0-4f52-b652-6ec4efb0d4e5","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[64],"y":[6.137]}},"id":"2695fd3c-2003-4bae-86fe-67735bc141d3","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d0d20b92-b0dd-45a1-afa0-9c890273dd73","type":"Circle"},{"attributes":{"formatter":{"id":"31ebdb2d-13b1-45a8-b5d8-3e01fbb256dd","type":"BasicTickFormatter"},"plot":{"id":"fed8f870-3215-46b4-be56-e9d95a6a496d","subtype":"Figure","type":"Plot"},"ticker":{"id":"c52054c5-760e-4550-9efd-7eb5f816b9a3","type":"BasicTicker"}},"id":"26e9aa14-272a-4168-ba7f-89e4172acf2a","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"fed8f870-3215-46b4-be56-e9d95a6a496d","subtype":"Figure","type":"Plot"},"ticker":{"id":"eae1f656-95bd-48a9-84c5-41c6a08f8758","type":"BasicTicker"}},"id":"43ecbcfe-bedc-4871-b7d5-0e501ba7a750","type":"Grid"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ff0067b7-debf-4efc-be3a-b573d6fbe140","type":"Circle"},{"attributes":{},"id":"eae1f656-95bd-48a9-84c5-41c6a08f8758","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"30e0b364-7afd-430f-a9d7-0e93804985b9","type":"Circle"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[64],"y":[9.705]}},"id":"3a2a71b7-33a5-41d7-a735-f65c384f8d07","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f0dba22b-3ca4-41b3-9863-5b1a1245d9b8","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"e4e7b6cb-4cf3-4737-886c-f95839216821","type":"DataRange1d"},{"attributes":{"p ...
